# %%
# AI is used to reduce the work by human beings
#AI divided into 3 compenents mainly
# 1.machine learning
# 2.Deep learning
# 3.Natural language processing

# %%
#Data divided into 3 types
# 1.structed data (excel sheet)
# 2. unstructed data(images,videos)
# 3.semistructed data(text,speech)

# %%
# 1.structed data means what we all see or visible by eye
# 2.unstructed data means what we dont see by human eye
# 3.semistructed data means what we see little bit dont see little bit

# %%
# data is given to algorithm and is converted into model and model will precidict
# algorithm means which learns from data and still learning state
# model means which completed learning stage and model will give the predictions

# %%
# Giving excel data to maths 0r algorithm is known as machine learning
# applications of machine learning like churun,gmail
# machine learning means which learns everthing from data and do predictions and learn from past experiences

# %%
# machine learning divided into 3 types
# 1.supervised
# 2.unsupervised
# 3.reinforcement

# %%
# 1.supervised means which is having both independent and dependent coloumns
# 2.supervised divided into 2 types
# 1.regression
# 2.classification

# %%
#types of columns
# 1. numerical column
# 2.categorical column
# 3.date and time
# 4.boolean column

# %%
# 1.numerical column divided into 2 types
# 1.descrete means staright forward value (ex: age column)
# 2.continous means a range of values(height os man)
# 2. categorical column divided into 2 types
# 1.nominal means every label have the same priority
# 2.odinal means every label have different priority

# %%
# In Meacine Learning from supervised from regression
# regression means having both independent and dependent columns where dependent column should be continious

# %%
#In Meacine Learning from supervised from classification
# classification means having both independent and dependent columns where dependent column should be boolean or multiboolean or discrete

# %%
#In Meacine Learning from unsupervised means the data having only independent columns
#unsuperised is divided into 2 types
#1.clustering means grouping the data
#2.assosication means suggesting locations

# %%
#In Meacine Learning from supervised from regression
# regression is divided into types
# 1. simple linear regression means one independent and one dependent column
# x - means independent
# y_ means dependent
# ones  the data is created  its divided into Train,Test,Split
